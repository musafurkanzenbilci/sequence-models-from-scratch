# %%
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import Dataset
import torch.optim as optim
from nltk.translate.bleu_score import sentence_bleu , SmoothingFunction

# %%
def sentence_to_words(sentence):
    words = sentence.split()
    last = words.pop()
    last, end = last[:-1], last[-1]
    words.append(last)
    words.append(end)
    return words

# %%
class TrEngDataset(Dataset):
    def __init__(self, path=None, limit=None):
        self.path = "/Users/musazenbilci/Desktop/mosesopposite/bisiler/nlp/basic_rnn/data/tur-eng/tur.txt" if not path else path
        self.data = []
        self._wordlimits = [84, 1123, 28555]
        count = 0
        with open(self.path, "r") as f:
            line = f.readline()
            while line:
                count+=1
                if limit and self._wordlimits[limit-1] < count:
                    break
                eng, tr = line.split('\t')[:2]
                self.data.append((tr, eng))
                line = f.readline()


    def __getitem__(self, index):
        return super().__getitem__(index)
    
    def __len__(self):
        return len(self.data)

# %%
dataset = TrEngDataset(limit=2)

# %%
len(dataset.data)
# Out:
# 28555

# %%
class Vocabulary():
    def __init__(self, sentence_list):
        self.vocab = {}
        self.sos_token = "<SOS>"
        self.eos_token = "<EOS>"
        self.pad_token = "<PAD>"
        self.vocab_size = 0
        for token in [self.sos_token, self.eos_token, self.pad_token]:
            self.vocab[token] = self.vocab_size
            self.vocab_size+=1

        for sentence in sentence_list:
            words = sentence_to_words(sentence)
            for word in words:
                if word not in self.vocab:
                    self.vocab[word] = self.vocab_size
                    self.vocab_size+=1

        self.i2w = {index: word for word, index in self.vocab.items()}
    
    def get_word(self, index):
        return self.i2w[index]
    
    def get_index(self, word):
        return self.vocab.get(word, 'NAN')

# %%
turkish_sentences = np.array(dataset.data)[:,0]
tr_vocab = Vocabulary(turkish_sentences)
english_sentences = np.array(dataset.data)[:,1]
eng_vocab = Vocabulary(english_sentences)

# %%
class LSTMCell(nn.Module):
    def __init__(self, input_size, hidden_size):
        super().__init__()
        combined_size = input_size + hidden_size
        # forget gate
        self.forget = nn.Linear(combined_size, hidden_size, bias=True)
        # update gate
        self.update = nn.Linear(combined_size, hidden_size, bias=True)
        # candidate gate
        self.candidate = nn.Linear(combined_size, hidden_size, bias=True)
        # output gate
        self.output = nn.Linear(combined_size, hidden_size, bias=True)
    
    def forward(self, x, prev_a, prev_c):
        input_vector = torch.concat((x, prev_a))
        forget = torch.sigmoid(self.forget(input_vector))
        update = torch.sigmoid(self.update(input_vector))
        candidate = torch.tanh(self.candidate(input_vector))
        output = torch.sigmoid(self.output(input_vector))

        c = (forget * prev_c) + (update * candidate)
        a =  torch.tanh(c) * output

        return a, c

class LSTMStacked(nn.Module):
    def __init__(self, num_layers, input_size, hidden_size, output_size):
        super().__init__()
        self.num_layers = num_layers
        self.cells = nn.Sequential(LSTMCell(input_size, hidden_size), *(LSTMCell(hidden_size, hidden_size) for _ in range(self.num_layers)))
        self.final = nn.Linear(hidden_size, output_size, bias=True)
    
    def forward(self, x, prev_a_c_list):
        new_a_c_list = []
        for c in range(self.num_layers):
            prev_a, prev_c = prev_a_c_list[c]
            new_a, new_c = self.cells[c](x, prev_a, prev_c)
            new_a_c_list.append((new_a, new_c))
            x = new_a
        
        x = self.final(x)
        return x, new_a_c_list

# %%
make_word_onehot = lambda word, vocab: nn.functional.one_hot(torch.tensor(vocab.get_index(word)), num_classes=vocab.vocab_size).to(torch.float32)

# %%
class Seq2Seq(nn.Module):
    def __init__(self, vocab, output_vocab, hidden_size, num_layers=3, sos_token='<SOS>'):
        super().__init__()
        self.vocab = vocab
        self.output_vocab = output_vocab
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.sos_token = sos_token
        self.eos_token_indexes = [self.output_vocab.get_index(token) for token in [self.vocab.eos_token, '.', '!', '?']]
        self.encoder = LSTMStacked(self.num_layers, self.vocab.vocab_size, hidden_size, hidden_size)
        self.decoder = LSTMStacked(self.num_layers, self.output_vocab.vocab_size, hidden_size, self.output_vocab.vocab_size)
    
    def forward(self, seq, target_seq):
        a_c_0 = [(torch.zeros(self.hidden_size), torch.zeros(self.hidden_size)) for _ in range(self.num_layers)]
        prev_a_c = a_c_0
        for word in seq:
            _, prev_a_c = self.encoder(word, prev_a_c)

        input = make_word_onehot(self.sos_token, self.output_vocab)
        target_seq = [input] + target_seq
        output = []
        for target_word in target_seq:
            input, prev_a_c = self.decoder(target_word, prev_a_c)
            output.append(input)
        
        return output

    def predict(self, seq):
        a_c_0 = [(torch.zeros(self.hidden_size), torch.zeros(self.hidden_size)) for _ in range(self.num_layers)]
        prev_a_c = a_c_0
        for word in seq:
            _, prev_a_c = self.encoder(word, prev_a_c)

        input = make_word_onehot(self.sos_token, self.output_vocab)
        output = []
        
        while torch.argmax(input) not in self.eos_token_indexes and len(output) < len(seq)+5: 
            input, prev_a_c = self.decoder(input, prev_a_c)
            output.append(input)
        
        return output

# %%
def pad_couple(first, sec, pad):
    while len(first) > len(sec):
        sec.append(pad)
    while len(sec) > len(first):
        first.append(pad)
    return first, sec

# %%
torch.set_grad_enabled(True)

model = Seq2Seq(tr_vocab, eng_vocab, hidden_size=64)#181epoch
initial_lr = 1e-3
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=initial_lr, momentum=0.9, weight_decay=0.0005)
lr_scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=10)
EPOCHS = 1

for ep in range(EPOCHS):
    epoch_loss = 0
    count = 0
    for s in range(len(turkish_sentences)):
        count+=1
        # print(f"Going for the {count}. with input {turkish_sentences[s]} and output {english_sentences[s]}")
        optimizer.zero_grad()
        
        sentence = turkish_sentences[s]
        word_list = sentence_to_words(sentence)
        embedding_list = [make_word_onehot(word, tr_vocab) for word in word_list]

        target_sentence = english_sentences[s]
        target_list = sentence_to_words(target_sentence)
        target_embedding_list = [make_word_onehot(word, eng_vocab) for word in target_list]

        logits = model(embedding_list, target_embedding_list)

        if len(logits) != len(target_embedding_list):
            logits, target_embedding_list = pad_couple(logits, target_embedding_list, make_word_onehot(eng_vocab.pad_token, eng_vocab))
        
        loss = 0
        for i in range(len(logits)):
            loss += criterion(logits[i], target_embedding_list[i])
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    print("EPOCH", ep, epoch_loss / len(turkish_sentences))
    lr_scheduler.step(epoch_loss / len(turkish_sentences))
# print([eng_vocab.get_word(torch.argmax(logit).item()) for logit in logits])
# print(target_embedding_list[0].shape)

# %%
torch.set_grad_enabled(False)
try:
    chencherry = SmoothingFunction()
    test_count = 0
    outputs = []
    targets = []
    total_bleu_score = 0
    for s in range(len(turkish_sentences)):
        test_count+=1
        print(f"Going for the {test_count}. with input {turkish_sentences[s]} and output {english_sentences[s]}")
        
        sentence = turkish_sentences[s]
        word_list = sentence_to_words(sentence)
        embedding_list = [make_word_onehot(word, tr_vocab) for word in word_list]

        target_sentence = english_sentences[s]
        target_list = sentence_to_words(target_sentence)
        target_embedding_list = [make_word_onehot(word, eng_vocab) for word in target_list]

        logits = model.predict(embedding_list)
        probs = [torch.softmax(logit, 0) for logit in logits]
        # print(probs)
        output = [eng_vocab.get_word(torch.argmax(prob).item()) for prob in probs]
        while output[-1] == eng_vocab.pad_token:
            output.pop()
        outputs.append(output)
        targets.append([target_list])
        # score = bleu_score(target_list, output)
        print('Output', output)
        print('Target', target_list)
        # print('Score', score)
        # break
        score = sentence_bleu([target_list], output, smoothing_function=chencherry.method2)
        total_bleu_score += score
        print('Score', score)
    print('Total Avg Score', total_bleu_score / len(turkish_sentences))
    
finally:
    torch.set_grad_enabled(True)
# Out:
# Going for the 1. with input Selam. and output Hi.
# Output ['Hello', 'OK', '!']
# Target ['Hi', '.']
# Score 0
# Going for the 2. with input Merhaba. and output Hi.
# Output ['Wash', 'OK', 'up']
# Target ['Hi', '.']
# Score 0
# Going for the 3. with input Kaç! and output Run!
# Output ['Run', 'me', '!']
# Target ['Run', '!']
# Score 0.4854917717073234
# Going for the 4. with input Koş! and output Run!
# Output ['Run', 'me', '!']
# Target ['Run', '!']
# Score 0.4854917717073234
# Going for the 5. with input Kaç! and output Run.
# Output ['Run', 'me', '!']
# Target ['Run', '.']
# Score 0.408248290463863
# Going for the 6. with input Koş! and output Run.
# Output ['Run', 'me', '!']
# Target ['Run', '.']
# Score 0.408248290463863
# Going for the 7. with input Kim? and output Who?
# Output ['Who', 'up']
# Target ['Who', '?']
# Score 0.5
# Going for the 8. with input Vay canına! and output Wow!
# Output ['Stand', 'him', '!']
# Target ['Wow', '!']
# Score 0.408248290463863
# Going for the 9. with input Ördek! and output Duck!
# Output ['Wake', 'it', '!']
# Target ['Duck', '!']
# Score 0.408248290463863
# Going for the 10. with input Ateş! and output Fire!
# Output ['Shoot', 'up']
# Target ['Fire', '!']
# Score 0
# Going for the 11. with input Yangın! and output Fire!
# Output ['Get', 'up']
# Target ['Fire', '!']
# Score 0
# Going for the 12. with input Ateş et! and output Fire!
# Output ['Shoot', 'on', 'up', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Fire', '!']
# Score 0.13888095170058956
# Going for the 13. with input Yardım et! and output Help!
# Output ['Help', 'it', '!']
# Target ['Help', '!']
# Score 0.4854917717073234
# Going for the 14. with input İmdat! and output Help!
# Output ['No', '!']
# Target ['Help', '!']
# Score 0.5
# Going for the 15. with input Atla! and output Jump!
# Output ['Jump', '.']
# Target ['Jump', '!']
# Score 0.5
# Going for the 16. with input Defol. and output Jump.
# Output ['Get', 'up', '.']
# Target ['Jump', '.']
# Score 0.408248290463863
# Going for the 17. with input Git! and output Jump.
# Output ['Jump', '.']
# Target ['Jump', '.']
# Score 0.7071067811865476
# Going for the 18. with input Atla! and output Jump.
# Output ['Jump', '.']
# Target ['Jump', '.']
# Score 0.7071067811865476
# Going for the 19. with input Kal. and output Stay.
# Output ['Stay', 'give', '.']
# Target ['Stay', '.']
# Score 0.4854917717073234
# Going for the 20. with input Dur! and output Stop!
# Output ['Stop', '!']
# Target ['Stop', '!']
# Score 0.7071067811865476
# Going for the 21. with input Bırak! and output Stop!
# Output ['Stop', '.']
# Target ['Stop', '!']
# Score 0.5
# Going for the 22. with input Bekle. and output Wait.
# Output ['Get', 'up', '.']
# Target ['Wait', '.']
# Score 0.408248290463863
# Going for the 23. with input Onu yap. and output Do it.
# Output ['I', 'saw', 'it', 'me', '<PAD>', '<PAD>', '<PAD>', 'it']
# Target ['Do', 'it', '.']
# Score 0.13888095170058956
# Going for the 24. with input Devam et. and output Go on.
# Output ['Go', 'home', '.']
# Target ['Go', 'on', '.']
# Score 0.4854917717073234
# Going for the 25. with input Devam edin! and output Go on.
# Output ['Go', 'back', '.']
# Target ['Go', 'on', '.']
# Score 0.4854917717073234
# Going for the 26. with input Selam. and output Hello!
# Output ['Hello', 'OK', '!']
# Target ['Hello', '!']
# Score 0.4854917717073234
# Going for the 27. with input Merhaba. and output Hello.
# Output ['Wash', 'OK', 'up']
# Target ['Hello', '.']
# Score 0
# Going for the 28. with input Acele et! and output Hurry!
# Output ['Hurry', 'off', '!']
# Target ['Hurry', '!']
# Score 0.4854917717073234
# Going for the 29. with input Koştum. and output I ran.
# Output ['I', 'ran', 'Tom', 'me', 'up']
# Target ['I', 'ran', '.']
# Score 0.33980884896942454
# Going for the 30. with input Anlıyorum. and output I see.
# Output ['I', 'get', 'Tom', 'me', 'me']
# Target ['I', 'see', '.']
# Score 0.24028114141347542
# Going for the 31. with input Görüyorum. and output I see.
# Output ['I', 'see', 'Tom', 'it', 'me']
# Target ['I', 'see', '.']
# Score 0.33980884896942454
# Going for the 32. with input Kazandım. and output I won.
# Output ['I', 'won', 'it', 'go']
# Target ['I', 'won', '.']
# Score 0.4518010018049224
# Going for the 33. with input Oh hayır! and output Oh no!
# Output ["It's", 'him', 'it', '!']
# Target ['Oh', 'no', '!']
# Score 0.31947155212313627
# Going for the 34. with input Rahatla. and output Relax.
# Output ['Loosen', 'it', 'up']
# Target ['Relax', '.']
# Score 0
# Going for the 35. with input Ateş! and output Shoot!
# Output ['Shoot', 'up']
# Target ['Shoot', '!']
# Score 0.5
# Going for the 36. with input Ateş et! and output Shoot!
# Output ['Shoot', 'on', 'up', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Shoot', '!']
# Score 0.16515821590069035
# Going for the 37. with input Vur! and output Shoot!
# Output ['Shoot', 'up', '<PAD>', '<PAD>', '!']
# Target ['Shoot', '!']
# Score 0.28574404296988
# Going for the 38. with input Gülümse. and output Smile.
# Output ['Open', 'up', '.']
# Target ['Smile', '.']
# Score 0.408248290463863
# Going for the 39. with input Saldır! and output Attack!
# Output ['Attack', '!']
# Target ['Attack', '!']
# Score 0.7071067811865476
# Going for the 40. with input Hücum! and output Attack!
# Output ['Attack', '!']
# Target ['Attack', '!']
# Score 0.7071067811865476
# Going for the 41. with input Yarasın! and output Cheers!
# Output ['Thanks', '!']
# Target ['Cheers', '!']
# Score 0.5
# Going for the 42. with input Şerefe. and output Cheers!
# Output ['Thanks', 'up', '<PAD>', '<PAD>', '!']
# Target ['Cheers', '!']
# Score 0.24028114141347542
# Going for the 43. with input Bunu ye. and output Eat it.
# Output ['Try', 'me', 'me', 'me', 'me']
# Target ['Eat', 'it', '.']
# Score 0
# Going for the 44. with input Silip süpür. and output Eat up.
# Output ['I', 'it', 'it', '.']
# Target ['Eat', 'up', '.']
# Score 0.31947155212313627
# Going for the 45. with input Soluk ver. and output Exhale.
# Output ['I', 'am', 'up', '.']
# Target ['Exhale', '.']
# Score 0.31947155212313627
# Going for the 46. with input Kımıldama! and output Freeze!
# Output ['Stay', 'down', '!']
# Target ['Freeze', '!']
# Score 0.408248290463863
# Going for the 47. with input Olduğun yerde kal! and output Freeze!
# Output ['Get', 'care', '!']
# Target ['Freeze', '!']
# Score 0.408248290463863
# Going for the 48. with input Şimdi git. and output Go now.
# Output ['Go', 'that', 'up', '.']
# Target ['Go', 'now', '.']
# Score 0.37991784282579627
# Going for the 49. with input Haydi git. and output Go now.
# Output ['Go', 'that', '.']
# Target ['Go', 'now', '.']
# Score 0.4854917717073234
# Going for the 50. with input Git artık. and output Go now.
# Output ['Go', 'that', 'up', '.']
# Target ['Go', 'now', '.']
# Score 0.37991784282579627
# Going for the 51. with input Gidin artık. and output Go now.
# Output ['Go', 'that', '.']
# Target ['Go', 'now', '.']
# Score 0.4854917717073234
# Going for the 52. with input Anladım! and output Got it!
# Output ['Wake', 'me', "It's", "It's", "It's", '!']
# Target ['Got', 'it', '!']
# Score 0.19304869754804482
# Going for the 53. with input Anladın mı? and output Got it?
# Output ['Am', 'what', '?']
# Target ['Got', 'it', '?']
# Score 0.408248290463863
# Going for the 54. with input O koştu. and output He ran.
# Output ['He', 'Tom', '.']
# Target ['He', 'ran', '.']
# Score 0.4854917717073234
# Going for the 55. with input Atla. and output Hop in.
# Output ["I'm", 'won', '.']
# Target ['Hop', 'in', '.']
# Score 0.408248290463863
# Going for the 56. with input Ben düştüm. and output I fell.
# Output ['I', 'fell', 'it']
# Target ['I', 'fell', '.']
# Score 0.5773502691896257
# Going for the 57. with input Örgü örüyorum. and output I knit.
# Output ['I', 'slept', 'it', '<PAD>', '<PAD>', '<PAD>', 'nice', '!']
# Target ['I', 'knit', '.']
# Score 0.13888095170058956
# Going for the 58. with input Biliyorum. and output I know.
# Output ['I', 'see', 'Tom', 'it', 'me']
# Target ['I', 'know', '.']
# Score 0.24028114141347542
# Going for the 59. with input Ben ayrıldım. and output I left.
# Output ['I', 'got', '.']
# Target ['I', 'left', '.']
# Score 0.4854917717073234
# Going for the 60. with input Ödedim. and output I paid.
# Output ['I', 'paid', 'it', 'it', '!']
# Target ['I', 'paid', '.']
# Score 0.33980884896942454
# Going for the 61. with input Ben yokum. and output I pass.
# Output ['I', 'was', '.']
# Target ['I', 'pass', '.']
# Score 0.4854917717073234
# Going for the 62. with input Pas geçiyorum. and output I pass.
# Output ['I', 'got', '.']
# Target ['I', 'pass', '.']
# Score 0.4854917717073234
# Going for the 63. with input Ben istifa ettim. and output I quit.
# Output ['I', 'ate', 'out', '.']
# Target ['I', 'quit', '.']
# Score 0.37991784282579627
# Going for the 64. with input Yüzerim. and output I swim.
# Output ['I', 'was', 'it', 'you', '.']
# Target ['I', 'swim', '.']
# Score 0.28574404296988
# Going for the 65. with input Çalışıyorum. and output I work.
# Output ['I', 'see', '.']
# Target ['I', 'work', '.']
# Score 0.4854917717073234
# Going for the 66. with input Ben 19 yaşındayım. and output I'm 19.
# Output ["I'm", "I'm", 'away', '.']
# Target ["I'm", '19', '.']
# Score 0.37991784282579627
# Going for the 67. with input Ben iyiyim. and output I'm OK.
# Output ['I', 'am', "I'm", '.']
# Target ["I'm", 'OK', '.']
# Score 0.37991784282579627
# Going for the 68. with input Ben uyanığım. and output I'm up.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'up', '.']
# Score 0.4854917717073234
# Going for the 69. with input Soluk al. and output Inhale.
# Output ['Inhale', 'am', 'in', '.']
# Target ['Inhale', '.']
# Score 0.37991784282579627
# Going for the 70. with input Mümkün değil! and output No way!
# Output ["It's", 'love', '!']
# Target ['No', 'way', '!']
# Score 0.408248290463863
# Going for the 71. with input Asla! and output No way!
# Output ['Cheer', '!']
# Target ['No', 'way', '!']
# Score 0.3032653298563167
# Going for the 72. with input Gerçekten mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 73. with input Valla mı? and output Really?
# Output ['Seriously', "I'm", "I'm", '?']
# Target ['Really', '?']
# Score 0.31947155212313627
# Going for the 74. with input Esas mı? and output Really?
# Output ['Seriously', "I'm", "I'm", '?']
# Target ['Really', '?']
# Score 0.31947155212313627
# Going for the 75. with input Harbi mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 76. with input Harbiden mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 77. with input Sahiden mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 78. with input Hakikaten mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 79. with input Harbici misin? and output Really?
# Output ['Seriously', 'course', 'win', 'win', 'win', 'win', '?']
# Target ['Really', '?']
# Score 0.16149930819624292
# Going for the 80. with input Cidden mi? and output Really?
# Output ['Seriously', 'am', '?']
# Target ['Really', '?']
# Score 0.408248290463863
# Going for the 81. with input Teşekkür ederim! and output Thanks!
# Output ['Grab', 'on', 'up', '!']
# Target ['Thanks', '!']
# Score 0.31947155212313627
# Going for the 82. with input Teşekkürler! and output Thanks!
# Output ['Thanks', '!']
# Target ['Thanks', '!']
# Score 0.7071067811865476
# Going for the 83. with input Teşekkürler. and output Thanks.
# Output ['Thanks', 'up', '!']
# Target ['Thanks', '.']
# Score 0.408248290463863
# Going for the 84. with input Teşekkür ettim. and output Thanks.
# Output ['I', 'him', '.']
# Target ['Thanks', '.']
# Score 0.408248290463863
# Going for the 85. with input Bunu dene. and output Try it.
# Output ['Try', 'this', 'me', 'me', '.']
# Target ['Try', 'it', '.']
# Score 0.28574404296988
# Going for the 86. with input Biz yemek yedik. and output We ate.
# Output ['We', 'Get', 'away', '.']
# Target ['We', 'ate', '.']
# Score 0.37991784282579627
# Going for the 87. with input Biz deneriz. and output We try.
# Output ['We', 'smiled', '.']
# Target ['We', 'try', '.']
# Score 0.4854917717073234
# Going for the 88. with input Biz çabalarız. and output We try.
# Output ['We', 'smiled', '.']
# Target ['We', 'try', '.']
# Score 0.4854917717073234
# Going for the 89. with input Biz kazandık. and output We won.
# Output ['We', 'hung', '.']
# Target ['We', 'won', '.']
# Score 0.4854917717073234
# Going for the 90. with input Neden ben? and output Why me?
# Output ['Why', 'Why', 'it', '?']
# Target ['Why', 'me', '?']
# Score 0.37991784282579627
# Going for the 91. with input Niçin ben? and output Why me?
# Output ['Why', 'I', 'it', '?']
# Target ['Why', 'me', '?']
# Score 0.37991784282579627
# Going for the 92. with input Niye ben? and output Why me?
# Output ['Why', 'I', 'it', '?']
# Target ['Why', 'me', '?']
# Score 0.37991784282579627
# Going for the 93. with input Tom'a sor. and output Ask Tom.
# Output ['Ask', 'Tom', '.']
# Target ['Ask', 'Tom', '.']
# Score 0.8408964152537145
# Going for the 94. with input Ona sor. and output Ask him.
# Output ['Ask', 'it', 'it', '!']
# Target ['Ask', 'him', '.']
# Score 0.31947155212313627
# Going for the 95. with input Sakin olun. and output Be calm.
# Output ['Stay', 'cool', '.']
# Target ['Be', 'calm', '.']
# Score 0.408248290463863
# Going for the 96. with input Sakin ol. and output Be cool.
# Output ['Keep', 'down', '.']
# Target ['Be', 'cool', '.']
# Score 0.408248290463863
# Going for the 97. with input Rahat ol. and output Be cool.
# Output ['Be', 'calm', 'cool', '.']
# Target ['Be', 'cool', '.']
# Score 0.5
# Going for the 98. with input Adil ol. and output Be fair.
# Output ['Stay', 'over', 'cool', '.']
# Target ['Be', 'fair', '.']
# Score 0.31947155212313627
# Going for the 99. with input Nazik ol. and output Be kind.
# Output ['Be', 'give', 'in', '.']
# Target ['Be', 'kind', '.']
# Score 0.37991784282579627
# Going for the 100. with input Kibar ol. and output Be nice.
# Output ['Be', 'give', 'in', '.']
# Target ['Be', 'nice', '.']
# Score 0.37991784282579627
# Going for the 101. with input Nazik ol. and output Be nice.
# Output ['Be', 'give', 'in', '.']
# Target ['Be', 'nice', '.']
# Score 0.37991784282579627
# Going for the 102. with input Defol. and output Beat it.
# Output ['Get', 'up', '.']
# Target ['Beat', 'it', '.']
# Score 0.408248290463863
# Going for the 103. with input Yak onu. and output Burn it.
# Output ["It's", 'him', 'it', 'it', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Burn', 'it', '.']
# Score 0.13888095170058956
# Going for the 104. with input Onu göm. and output Bury it.
# Output ['I', 'it', 'it', '!']
# Target ['Bury', 'it', '.']
# Score 0.31947155212313627
# Going for the 105. with input Ara beni. and output Call me.
# Output ['Tell', 'this', '.']
# Target ['Call', 'me', '.']
# Score 0.408248290463863
# Going for the 106. with input Gelin. and output Come in.
# Output ['Come', 'Be', 'out', '.']
# Target ['Come', 'in', '.']
# Score 0.37991784282579627
# Going for the 107. with input Kapat şu konuyu artık! and output Drop it!
# Output ['Drop', 'it', 'it', '!']
# Target ['Drop', 'it', '!']
# Score 0.5533409598501607
# Going for the 108. with input Onu katla. and output Fold it.
# Output ['I', 'it', 'it', 'it']
# Target ['Fold', 'it', '.']
# Score 0.31947155212313627
# Going for the 109. with input Tom'u alın. and output Get Tom.
# Output ['Grab', 'Tom', 'Tom', '.']
# Target ['Get', 'Tom', '.']
# Score 0.4518010018049224
# Going for the 110. with input Çık dışarı! and output Get out!
# Output ['Get', 'that', 'out', '.']
# Target ['Get', 'out', '!']
# Score 0.37991784282579627
# Going for the 111. with input Defol! and output Get out!
# Output ['Get', 'up', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Get', 'out', '!']
# Score 0.19205612637498934
# Going for the 112. with input Yürü git! and output Get out!
# Output ['Get', 'fire', 'up', '!']
# Target ['Get', 'out', '!']
# Score 0.37991784282579627
# Going for the 113. with input Defol. and output Get out.
# Output ['Get', 'up', '.']
# Target ['Get', 'out', '.']
# Score 0.4854917717073234
# Going for the 114. with input Defol. and output Go away!
# Output ['Get', 'up', '.']
# Target ['Go', 'away', '!']
# Score 0
# Going for the 115. with input Yürü git! and output Go away!
# Output ['Get', 'fire', 'up', '!']
# Target ['Go', 'away', '!']
# Score 0.31947155212313627
# Going for the 116. with input Defol. and output Go away.
# Output ['Get', 'up', '.']
# Target ['Go', 'away', '.']
# Score 0.408248290463863
# Going for the 117. with input Geri dön. and output Go back.
# Output ["I'll", 'back', '.']
# Target ['Go', 'back', '.']
# Score 0.5773502691896257
# Going for the 118. with input Eve git. and output Go home.
# Output ['Go', 'up', '.']
# Target ['Go', 'home', '.']
# Score 0.4854917717073234
# Going for the 119. with input Yavaş git. and output Go slow.
# Output ['Go', 'won', '.']
# Target ['Go', 'slow', '.']
# Score 0.4854917717073234
# Going for the 120. with input Hoşça kalın. and output Goodbye!
# Output ['Goodbye', 'this', 'Grab', '.']
# Target ['Goodbye', '!']
# Score 0.31947155212313627
# Going for the 121. with input Hoşça kal. and output Goodbye!
# Output ['Goodbye', 'this', 'Grab', '.']
# Target ['Goodbye', '!']
# Score 0.31947155212313627
# Going for the 122. with input Güle güle. and output Goodbye!
# Output ['Stand', 'this', 'this', '.']
# Target ['Goodbye', '!']
# Score 0
# Going for the 123. with input Allah'a ısmarladık! and output Goodbye!
# Output ['Goodbye', 'this', 'this', '!']
# Target ['Goodbye', '!']
# Score 0.37991784282579627
# Going for the 124. with input Allah'a emanet ol! and output Goodbye!
# Output ['Goodbye', 'this', '!']
# Target ['Goodbye', '!']
# Score 0.4854917717073234
# Going for the 125. with input Dayan! and output Hang on!
# Output ['Fantastic', '!']
# Target ['Hang', 'on', '!']
# Score 0.3032653298563167
# Going for the 126. with input Ha gayret! and output Hang on!
# Output ['Nice', 'won', '.']
# Target ['Hang', 'on', '!']
# Score 0
# Going for the 127. with input Geldi. and output He came.
# Output ['She', 'can', 'me']
# Target ['He', 'came', '.']
# Score 0
# Going for the 128. with input O koşar. and output He runs.
# Output ['She', 'Tom', '.']
# Target ['He', 'runs', '.']
# Score 0.408248290463863
# Going for the 129. with input Bana yardım et. and output Help me.
# Output ['Help', 'it', 'it', '!']
# Target ['Help', 'me', '.']
# Score 0.31947155212313627
# Going for the 130. with input Bize yardım et. and output Help us.
# Output ['Help', 'us', 'it', '.']
# Target ['Help', 'us', '.']
# Score 0.5
# Going for the 131. with input Merhaba, Tom. and output Hi, Tom.
# Output ['Hi,', 'Tom', 'Tom', 'me', 'me', '.']
# Target ['Hi,', 'Tom', '.']
# Score 0.3021375397356768
# Going for the 132. with input Tom'a vur. and output Hit Tom.
# Output ['Write', 'Tom', 'Tom', '.']
# Target ['Hit', 'Tom', '.']
# Score 0.4518010018049224
# Going for the 133. with input Olduğun yerde kal! and output Hold it!
# Output ['Get', 'care', '!']
# Target ['Hold', 'it', '!']
# Score 0.408248290463863
# Going for the 134. with input Bekle. and output Hold on.
# Output ['Get', 'up', '.']
# Target ['Hold', 'on', '.']
# Score 0.408248290463863
# Going for the 135. with input Ne kadar üzücü! and output How sad!
# Output ['How', 'sad', '!']
# Target ['How', 'sad', '!']
# Score 0.8408964152537145
# Going for the 136. with input Tom'a sarıl. and output Hug Tom.
# Output ['Humor', 'Tom', 'Tom', '.']
# Target ['Hug', 'Tom', '.']
# Score 0.4518010018049224
# Going for the 137. with input Kabul ediyorum. and output I agree.
# Output ['I', 'agree', 'it', 'it']
# Target ['I', 'agree', '.']
# Score 0.4518010018049224
# Going for the 138. with input Aynı fikirdeyim. and output I agree.
# Output ['I', 'agree', 'failed', '.']
# Target ['I', 'agree', '.']
# Score 0.5
# Going for the 139. with input Katılıyorum. and output I agree.
# Output ['I', 'can', 'Tom', 'me', 'me']
# Target ['I', 'agree', '.']
# Score 0.24028114141347542
# Going for the 140. with input Eğildim. and output I bowed.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'bowed', '.']
# Score 0.37991784282579627
# Going for the 141. with input Ağladım. and output I cried.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'cried', '.']
# Score 0.37991784282579627
# Going for the 142. with input Uyudum. and output I dozed.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'dozed', '.']
# Score 0.37991784282579627
# Going for the 143. with input Araba kullanırım. and output I drive.
# Output ['I', 'slept', 'it', 'OK', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['I', 'drive', '.']
# Score 0.13888095170058956
# Going for the 144. with input Araba sürdüm. and output I drove.
# Output ['I', 'drove', 'Tom', 'Tom', '<PAD>', '<PAD>', 'win', 'win']
# Target ['I', 'drove', '.']
# Score 0.19640732545025652
# Going for the 145. with input Taşındım. and output I moved.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'moved', '.']
# Score 0.37991784282579627
# Going for the 146. with input Ben uyudum. and output I slept.
# Output ['I', 'slept', 'Tom', '<PAD>', '<PAD>', '<PAD>', 'win', 'Keep']
# Target ['I', 'slept', '.']
# Score 0.19640732545025652
# Going for the 147. with input Ben sigara içiyorum. and output I smoke.
# Output ['I', 'can', 'Tom', '.']
# Target ['I', 'smoke', '.']
# Score 0.37991784282579627
# Going for the 148. with input Horladım. and output I snore.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'snore', '.']
# Score 0.37991784282579627
# Going for the 149. with input Durdum. and output I stood.
# Output ['I', 'see', 'Tom', '.']
# Target ['I', 'stood', '.']
# Score 0.37991784282579627
# Going for the 150. with input Ben yemin ettim. and output I swore.
# Output ['I', 'hurried', 'out', '.']
# Target ['I', 'swore', '.']
# Score 0.37991784282579627
# Going for the 151. with input Denedim. and output I tried.
# Output ['I', 'get', 'Tom', 'him']
# Target ['I', 'tried', '.']
# Score 0.31947155212313627
# Going for the 152. with input El salladım. and output I waved.
# Output ['I', 'noticed', 'it']
# Target ['I', 'waved', '.']
# Score 0.408248290463863
# Going for the 153. with input Gideceğim. and output I'll go.
# Output ["I'll", 'will', '.']
# Target ["I'll", 'go', '.']
# Score 0.4854917717073234
# Going for the 154. with input Ben Tom'um. and output I'm Tom.
# Output ['I', 'am', 'Tom', 'here', 'me']
# Target ["I'm", 'Tom', '.']
# Score 0.24028114141347542
# Going for the 155. with input Ben Tom. and output I'm Tom.
# Output ['I', 'Tom', 'Tom', 'Tom', 'me', 'OK']
# Target ["I'm", 'Tom', '.']
# Score 0.19304869754804482
# Going for the 156. with input Tom ben. and output I'm Tom.
# Output ['Tom', 'waved', 'Tom']
# Target ["I'm", 'Tom', '.']
# Score 0.408248290463863
# Going for the 157. with input Ben kötüyüm. and output I'm bad.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'bad', '.']
# Score 0.4854917717073234
# Going for the 158. with input Ben şişmanım. and output I'm fat.
# Output ["I'm", "I'm", 'fat']
# Target ["I'm", 'fat', '.']
# Score 0.5773502691896257
# Going for the 159. with input Şişmanım. and output I'm fat.
# Output ["I'm", "I'll", 'up', '.']
# Target ["I'm", 'fat', '.']
# Score 0.37991784282579627
# Going for the 160. with input Ben formdayım. and output I'm fit.
# Output ["I'm", 'quiet', 'fat', '.']
# Target ["I'm", 'fit', '.']
# Score 0.37991784282579627
# Going for the 161. with input Vuruldum! and output I'm hit!
# Output ["I'm", 'give', 'off', '!']
# Target ["I'm", 'hit', '!']
# Score 0.37991784282579627
# Going for the 162. with input Ben sıcaklıyorum. and output I'm hot.
# Output ['I', 'am', 'shy', 'am', '.']
# Target ["I'm", 'hot', '.']
# Score 0.24028114141347542
# Going for the 163. with input Ben hastayım. and output I'm ill.
# Output ['I', 'am', "I'm", '.']
# Target ["I'm", 'ill', '.']
# Score 0.37991784282579627
# Going for the 164. with input Hastayım. and output I'm ill.
# Output ['I', "I'll", 'ill', '.']
# Target ["I'm", 'ill', '.']
# Score 0.4518010018049224
# Going for the 165. with input Ben çılgınım. and output I'm mad.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'mad', '.']
# Score 0.4854917717073234
# Going for the 166. with input Ben yeniyim. and output I'm new.
# Output ["I'm", 'quiet', 'fat', '.']
# Target ["I'm", 'new', '.']
# Score 0.37991784282579627
# Going for the 167. with input Ben yaşlıyım. and output I'm old.
# Output ['I', 'am', 'shy', '.']
# Target ["I'm", 'old', '.']
# Score 0.31947155212313627
# Going for the 168. with input Ben üzgünüm. and output I'm sad.
# Output ["I'm", 'pass', '.']
# Target ["I'm", 'sad', '.']
# Score 0.4854917717073234
# Going for the 169. with input Ben utangacım. and output I'm shy.
# Output ["I'm", 'am', 'shy', '<PAD>', '<PAD>', '.']
# Target ["I'm", 'shy', '.']
# Score 0.25406637407730737
# Going for the 170. with input Benim! and output It's me!
# Output ["It's", 'it', '!']
# Target ["It's", 'me', '!']
# Score 0.4854917717073234
# Going for the 171. with input Onu sakla. and output Keep it.
# Output ['Keep', 'that', 'here', '.']
# Target ['Keep', 'it', '.']
# Score 0.37991784282579627
# Going for the 172. with input Öldür onu. and output Kill it.
# Output ["It's", 'OK', 'it', 'it', '<PAD>', '<PAD>', 'Keep', 'nice']
# Target ['Kill', 'it', '.']
# Score 0.13888095170058956
# Going for the 173. with input Beni öp. and output Kiss me.
# Output ['Forget', 'this', 'it', 'up', '<PAD>', '<PAD>', '<PAD>', 'it']
# Target ['Kiss', 'me', '.']
# Score 0
# Going for the 174. with input Onu kilitle. and output Lock it.
# Output ['I', 'it', 'it', 'it', '!']
# Target ['Lock', 'it', '.']
# Score 0.24028114141347542
# Going for the 175. with input Yukarı bak. and output Look up.
# Output ['Look', 'this', 'it', 'me']
# Target ['Look', 'up', '.']
# Score 0.31947155212313627
# Going for the 176. with input Ben de. and output Me, too.
# Output ["It's", 'am', 'Tom', '<PAD>', '<PAD>', '<PAD>', 'nice']
# Target ['Me,', 'too', '.']
# Score 0
# Going for the 177. with input Açınız. and output Open it.
# Output ["It's", 'OK', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Open', 'it', '.']
# Score 0
# Going for the 178. with input Açın. and output Open up.
# Output ['Hello', 'up', '.']
# Target ['Open', 'up', '.']
# Score 0.5773502691896257
# Going for the 179. with input Onu çek. and output Pull it.
# Output ['I', 'it', 'it', 'it', '!']
# Target ['Pull', 'it', '.']
# Score 0.24028114141347542
# Going for the 180. with input Onu ittir. and output Push it.
# Output ['I', 'it', 'it', 'it', '!']
# Target ['Push', 'it', '.']
# Score 0.24028114141347542
# Going for the 181. with input Kes şunu! and output Quit it!
# Output ["Let's", '!']
# Target ['Quit', 'it', '!']
# Score 0.3032653298563167
# Going for the 182. with input Görüşürüz. and output See you!
# Output ['See', 'go', '.']
# Target ['See', 'you', '!']
# Score 0.408248290463863
# Going for the 183. with input Görüşürüz. and output See you.
# Output ['See', 'go', '.']
# Target ['See', 'you', '.']
# Score 0.4854917717073234
# Going for the 184. with input Bana göster. and output Show me.
# Output ['Tell', 'this', '.']
# Target ['Show', 'me', '.']
# Score 0.408248290463863
# Going for the 185. with input Kapa çeneni! and output Shut up!
# Output ['Shut', 'I', '.']
# Target ['Shut', 'up', '!']
# Score 0.408248290463863
# Going for the 186. with input Kes sesini! and output Shut up!
# Output ['Shut', '<PAD>', 'give', '<PAD>', '!']
# Target ['Shut', 'up', '!']
# Score 0.28574404296988
# Going for the 187. with input Unut gitsin. and output Skip it.
# Output ['Forget', 'mine', 'him', 'up']
# Target ['Skip', 'it', '.']
# Score 0
# Going for the 188. with input Boş ver. and output Skip it.
# Output ['Forget', 'mine', 'it', '.']
# Target ['Skip', 'it', '.']
# Score 0.4518010018049224
# Going for the 189. with input Şimdilik hoşça kal. and output So long.
# Output ['Take', 'this', 'it', 'it', '.']
# Target ['So', 'long', '.']
# Score 0.24028114141347542
# Going for the 190. with input Kes şunu! and output Stop it.
# Output ["Let's", '!']
# Target ['Stop', 'it', '.']
# Score 0
# Going for the 191. with input Al senin olsun. and output Take it.
# Output ['Take', 'Tom', 'it', '.']
# Target ['Take', 'it', '.']
# Score 0.5
# Going for the 192. with input Söyle bana. and output Tell me.
# Output ['Tell', 'this', '.']
# Target ['Tell', 'me', '.']
# Score 0.4854917717073234
# Going for the 193. with input Bana söyle! and output Tell me.
# Output ['Tell', 'him', '!']
# Target ['Tell', 'me', '.']
# Score 0.408248290463863
# Going for the 194. with input Söyle bana! and output Tell me.
# Output ['Tell', 'him', '!']
# Target ['Tell', 'me', '.']
# Score 0.408248290463863
# Going for the 195. with input Tom yemek yedi. and output Tom ate.
# Output ['Tom', 'stood', 'Tom', 'stood', 'this', '.']
# Target ['Tom', 'ate', '.']
# Score 0.2295748846661433
# Going for the 196. with input Tom koştu. and output Tom ran.
# Output ['Tom', 'can', 'Tom', 'Tom', 'Tom', 'work']
# Target ['Tom', 'ran', '.']
# Score 0.19304869754804482
# Going for the 197. with input Bekleyin. and output Wait up.
# Output ['Loosen', 'it', '!']
# Target ['Wait', 'up', '.']
# Score 0
# Going for the 198. with input Kalk! and output Wake up!
# Output ['Wake', '!']
# Target ['Wake', 'up', '!']
# Score 0.36064528799877893
# Going for the 199. with input Uyan! and output Wake up!
# Output ['Wake', '!']
# Target ['Wake', 'up', '!']
# Score 0.36064528799877893
# Going for the 200. with input Yıkayın. and output Wash up.
# Output ['Wash', 'it', '!']
# Target ['Wash', 'up', '.']
# Score 0.408248290463863
# Going for the 201. with input Biz önemseriz. and output We care.
# Output ['We', 'on', '.']
# Target ['We', 'care', '.']
# Score 0.4854917717073234
# Going for the 202. with input Biliyoruz. and output We know.
# Output ['We', 'work', 'one', '.']
# Target ['We', 'know', '.']
# Score 0.37991784282579627
# Going for the 203. with input Biz kaybettik. and output We lost.
# Output ['We', 'agreed', '.']
# Target ['We', 'lost', '.']
# Score 0.4854917717073234
# Going for the 204. with input Kim yemek yedi? and output Who ate?
# Output ['Who', 'quit', '?']
# Target ['Who', 'ate', '?']
# Score 0.4854917717073234
# Going for the 205. with input Kim yedi? and output Who ate?
# Output ['Who', 'quit', '?']
# Target ['Who', 'ate', '?']
# Score 0.4854917717073234
# Going for the 206. with input Kim koştu? and output Who ran?
# Output ['Who', 'fell', '?']
# Target ['Who', 'ran', '?']
# Score 0.4854917717073234
# Going for the 207. with input Kim kazandı? and output Who won?
# Output ['Who', 'fell', '.']
# Target ['Who', 'won', '?']
# Score 0.408248290463863
# Going for the 208. with input Neden olmasın? and output Why not?
# Output ['Why', 'get', 'you', '?']
# Target ['Why', 'not', '?']
# Score 0.37991784282579627
# Going for the 209. with input Sen koşarsın. and output You run.
# Output ['You', 'hung', '.']
# Target ['You', 'run', '.']
# Score 0.4854917717073234
# Going for the 210. with input Sen kazandın. and output You won.
# Output ['You', 'hung', '.']
# Target ['You', 'won', '.']
# Score 0.4854917717073234
# Going for the 211. with input Kazandın. and output You won.
# Output ["We'll", 'off', '.']
# Target ['You', 'won', '.']
# Score 0.408248290463863
# Going for the 212. with input Süt ekleyin. and output Add milk.
# Output ['Say', 'it', 'it', 'it', '.']
# Target ['Add', 'milk', '.']
# Score 0.24028114141347542
# Going for the 213. with input Herkes ayağa kalksın. and output All rise.
# Output ['All', 'it', 'it', 'it', '<PAD>', '<PAD>', '<PAD>', 'Keep', '!']
# Target ['All', 'rise', '.']
# Score 0.12185174095150413
# Going for the 214. with input Kilolu muyum? and output Am I fat?
# Output ['Am', 'I', 'win', '?']
# Target ['Am', 'I', 'fat', '?']
# Score 0.5
# Going for the 215. with input Onlara sor. and output Ask them.
# Output ['Ask', 'around', 'it', '<PAD>', 'They', "I'm", 'quit', 'here']
# Target ['Ask', 'them', '.']
# Score 0.13888095170058956
# Going for the 216. with input Geri çekil! and output Back off!
# Output ['Jump', 'swam', '.']
# Target ['Back', 'off', '!']
# Score 0
# Going for the 217. with input Vazgeç! and output Back off!
# Output ['Back', 'down', '<PAD>', '!']
# Target ['Back', 'off', '!']
# Score 0.37991784282579627
# Going for the 218. with input Adam ol. and output Be a man.
# Output ['Stay', 'give', 'in', '.']
# Target ['Be', 'a', 'man', '.']
# Score 0.31947155212313627
# Going for the 219. with input Cesur ol. and output Be brave.
# Output ['Stay', 'down', '.']
# Target ['Be', 'brave', '.']
# Score 0.408248290463863
# Going for the 220. with input Kısa kesin. and output Be brief.
# Output ['Stay', 'cool', '.']
# Target ['Be', 'brief', '.']
# Score 0.408248290463863
# Going for the 221. with input Hızlı ol. and output Be quick.
# Output ['Be', 'am', 'cool', '.']
# Target ['Be', 'quick', '.']
# Score 0.37991784282579627
# Going for the 222. with input Sessiz ol. and output Be quiet.
# Output ['Stay', 'down', '.']
# Target ['Be', 'quiet', '.']
# Score 0.408248290463863
# Going for the 223. with input Sakin ol! and output Be still.
# Output ['Come', 'give', 'you', '.']
# Target ['Be', 'still', '.']
# Score 0.31947155212313627
# Going for the 224. with input Beni aşar. and output Beats me.
# Output ['Say', 'me', 'it', 'it', '<PAD>', '<PAD>', 'Keep', 'nice']
# Target ['Beats', 'me', '.']
# Score 0.13888095170058956
# Going for the 225. with input Aklım ermez. and output Beats me.
# Output ["It's", 'him', 'it', 'it', '<PAD>', '<PAD>', '<PAD>', 'nice']
# Target ['Beats', 'me', '.']
# Score 0
# Going for the 226. with input Defol. and output Buzz off.
# Output ['Get', 'up', '.']
# Target ['Buzz', 'off', '.']
# Score 0.408248290463863
# Going for the 227. with input Hoşça kal, Tom. and output Bye, Tom.
# Output ['Let', 'me', 'it', 'it', 'it', 'it', 'me']
# Target ['Bye,', 'Tom', '.']
# Score 0
# Going for the 228. with input Tom'u ara. and output Call Tom.
# Output ['Humor', 'Tom', 'Tom', '.']
# Target ['Call', 'Tom', '.']
# Score 0.4518010018049224
# Going for the 229. with input Gidebilir miyim? and output Can I go?
# Output ['Can', 'it', 'it', '?']
# Target ['Can', 'I', 'go', '?']
# Score 0.37991784282579627
# Going for the 230. with input Neşelen! and output Cheer up!
# Output ['Cheer', 'up', '!']
# Target ['Cheer', 'up', '!']
# Score 0.8408964152537145
# Going for the 231. with input Neşelen! and output Cheer up.
# Output ['Cheer', 'up', '!']
# Target ['Cheer', 'up', '.']
# Score 0.5773502691896257
# Going for the 232. with input Sakin ol! and output Cool off!
# Output ['Come', 'give', 'you', '.']
# Target ['Cool', 'off', '!']
# Score 0
# Going for the 233. with input Gitme. and output Don't go.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'go', '.']
# Score 0.4854917717073234
# Going for the 234. with input Sürmeye devam et. and output Drive on.
# Output ['Drive', 'on', 'it', '.']
# Target ['Drive', 'on', '.']
# Score 0.5
# Going for the 235. with input Tom'u bul. and output Find Tom.
# Output ['Stop', 'Tom', 'Tom', '.']
# Target ['Find', 'Tom', '.']
# Score 0.4518010018049224
# Going for the 236. with input Bunu düzelt. and output Fix this.
# Output ['Tell', 'this', '.']
# Target ['Fix', 'this', '.']
# Score 0.5773502691896257
# Going for the 237. with input Defol. and output Get away!
# Output ['Get', 'up', '.']
# Target ['Get', 'away', '!']
# Score 0.408248290463863
# Going for the 238. with input Yavaşla! and output Get down!
# Output ['Get', '!']
# Target ['Get', 'down', '!']
# Score 0.36064528799877893
# Going for the 239. with input Defol. and output Get lost.
# Output ['Get', 'up', '.']
# Target ['Get', 'lost', '.']
# Score 0.4854917717073234
# Going for the 240. with input Gerçekçi ol. and output Get real.
# Output ['Get', 'that', 'up', '.']
# Target ['Get', 'real', '.']
# Score 0.37991784282579627
# Going for the 241. with input Devam et. and output Go ahead.
# Output ['Go', 'home', '.']
# Target ['Go', 'ahead', '.']
# Score 0.4854917717073234
# Going for the 242. with input İçeri gir. and output Go on in.
# Output ['Go', 'up', '.']
# Target ['Go', 'on', 'in', '.']
# Score 0.3478700554542393
# Going for the 243. with input Tom'u alın. and output Grab Tom.
# Output ['Grab', 'Tom', 'Tom', '.']
# Target ['Grab', 'Tom', '.']
# Score 0.5533409598501607
# Going for the 244. with input Yakala onu. and output Grab him.
# Output ['Catch', 'it', 'it', 'it', 'it']
# Target ['Grab', 'him', '.']
# Score 0
# Going for the 245. with input Onu yakalayın. and output Grab him.
# Output ['Seize', 'it', 'it', '.']
# Target ['Grab', 'him', '.']
# Score 0.31947155212313627
# Going for the 246. with input Yakala onu! and output Grab him.
# Output ['Catch', 'him', 'it', 'it', '!']
# Target ['Grab', 'him', '.']
# Score 0.24028114141347542
# Going for the 247. with input Onu yakala! and output Grab him.
# Output ['Catch', 'him', 'it', 'it', '!']
# Target ['Grab', 'him', '.']
# Score 0.24028114141347542
# Going for the 248. with input Eğlenmenize bakın. and output Have fun.
# Output ["I'm", 'They', '.']
# Target ['Have', 'fun', '.']
# Score 0.408248290463863
# Going for the 249. with input Eğlen. and output Have fun.
# Output ['See', 'won', '.']
# Target ['Have', 'fun', '.']
# Score 0.408248290463863
# Going for the 250. with input O konuştu. and output He spoke.
# Output ['He', 'busy', '.']
# Target ['He', 'spoke', '.']
# Score 0.4854917717073234
# Going for the 251. with input O denedi. and output He tried.
# Output ["He's", 'him', '.']
# Target ['He', 'tried', '.']
# Score 0.408248290463863
# Going for the 252. with input O dener. and output He tries.
# Output ['He', 'Tom', '.']
# Target ['He', 'tries', '.']
# Score 0.4854917717073234
# Going for the 253. with input O ıslak. and output He's wet.
# Output ["He's", 'him', '.']
# Target ["He's", 'wet', '.']
# Score 0.4854917717073234
# Going for the 254. with input Tom'a yardım et. and output Help Tom.
# Output ['Help', 'Tom', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Help', 'Tom', '.']
# Score 0.1723243846523902
# Going for the 255. with input Merhaba, millet. and output Hi, guys.
# Output ['I', 'Tom', 'Tom', 'Tom', 'him', '.']
# Target ['Hi,', 'guys', '.']
# Score 0.19304869754804482
# Going for the 256. with input Ne kadar sevimli! and output How cute!
# Output ['How', 'you', '!']
# Target ['How', 'cute', '!']
# Score 0.4854917717073234
# Going for the 257. with input Ne kadar derin? and output How deep?
# Output ['Is', 'Tom', "It's", '?']
# Target ['How', 'deep', '?']
# Score 0.31947155212313627
# Going for the 258. with input Ne kadar güzel! and output How nice!
# Output ['How', 'it', '!']
# Target ['How', 'nice', '!']
# Score 0.4854917717073234
# Going for the 259. with input Beni idare et. and output Humor me.
# Output ['Humor', 'me', 'it', 'me', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['Humor', 'me', '.']
# Score 0.19640732545025652
# Going for the 260. with input Acele et! and output Hurry up.
# Output ['Hurry', 'off', '!']
# Target ['Hurry', 'up', '.']
# Score 0.408248290463863
# Going for the 261. with input Ben katıldım. and output I agreed.
# Output ['I', 'was', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', 'give']
# Target ['I', 'agreed', '.']
# Score 0.13888095170058956
# Going for the 262. with input Ben kabul ettim. and output I agreed.
# Output ['I', 'hurried', 'agreed', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['I', 'agreed', '.']
# Score 0.14490695731499714
# Going for the 263. with input Ben Tom'um. and output I am Tom.
# Output ['I', 'am', 'Tom', 'here', 'me']
# Target ['I', 'am', 'Tom', '.']
# Score 0.4949232003839765
# Going for the 264. with input Ben Tom. and output I am Tom.
# Output ['I', 'Tom', 'Tom', 'Tom', 'me', 'OK']
# Target ['I', 'am', 'Tom', '.']
# Score 0.2295748846661433
# Going for the 265. with input Tom ben. and output I am Tom.
# Output ['Tom', 'waved', 'Tom']
# Target ['I', 'am', 'Tom', '.']
# Score 0.2925226826055808
# Going for the 266. with input Ben geğirdim. and output I burped.
# Output ['I', 'slept', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['I', 'burped', '.']
# Score 0.13888095170058956
# Going for the 267. with input Ben gidebilirim. and output I can go.
# Output ['I', 'can', 'it', '<PAD>', '<PAD>', '<PAD>', "It's", 'nice']
# Target ['I', 'can', 'go', '.']
# Score 0.19640732545025652
# Going for the 268. with input Dans ettim. and output I danced.
# Output ['I', 'was', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', '!']
# Target ['I', 'danced', '.']
# Score 0.13888095170058956
# Going for the 269. with input Fena değildi. and output I did OK.
# Output ['I', 'him', 'it']
# Target ['I', 'did', 'OK', '.']
# Score 0.2925226826055808
# Going for the 270. with input Onu ben yaptım. and output I did it.
# Output ['I', 'made', 'it', 'it', '.']
# Target ['I', 'did', 'it', '.']
# Score 0.3760603093086394
# Going for the 271. with input Başarısız oldum. and output I failed.
# Output ['I', 'was', 'it', 'go']
# Target ['I', 'failed', '.']
# Score 0.31947155212313627
# Going for the 272. with input Unuttum. and output I forgot.
# Output ['I', 'see', '.']
# Target ['I', 'forgot', '.']
# Score 0.4854917717073234
# Going for the 273. with input Nefes nefese kaldım. and output I gasped.
# Output ['I', 'tripped', '.']
# Target ['I', 'gasped', '.']
# Score 0.4854917717073234
# Going for the 274. with input Nefesim kesildi. and output I gasped.
# Output ['I', 'mine', 'fat', 'Tom', 'me', '<PAD>', '<PAD>', 'it']
# Target ['I', 'gasped', '.']
# Score 0.13888095170058956
# Going for the 275. with input Geçimimi kıt kanaat sağlıyorum. and output I get by.
# Output ['I', 'get', 'it', 'it', 'it', 'me', '<PAD>', '<PAD>', '<PAD>', 'you']
# Target ['I', 'get', 'by', '.']
# Score 0.1535259783865636
# Going for the 276. with input Anlıyorum. and output I get it.
# Output ['I', 'get', 'Tom', 'me', 'me']
# Target ['I', 'get', 'it', '.']
# Score 0.33980884896942454
# Going for the 277. with input Gaf yaptım. and output I goofed.
# Output ['I', 'can', 'it', 'new', 'go']
# Target ['I', 'goofed', '.']
# Score 0.24028114141347542
# Going for the 278. with input Anladım. and output I got it.
# Output ['I', 'see', 'it', '.']
# Target ['I', 'got', 'it', '.']
# Score 0.5
# Going for the 279. with input Yardım ettim. and output I helped.
# Output ['I', 'helped', '.']
# Target ['I', 'helped', '.']
# Score 0.8408964152537145
# Going for the 280. with input Atladım. and output I jumped.
# Output ['I', 'can', 'it', 'go']
# Target ['I', 'jumped', '.']
# Score 0.31947155212313627
# Going for the 281. with input Baktım. and output I looked.
# Output ['I', 'was', 'up', 'go']
# Target ['I', 'looked', '.']
# Score 0.31947155212313627
# Going for the 282. with input Ben inledim. and output I moaned.
# Output ['I', 'fell', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', 'nice']
# Target ['I', 'moaned', '.']
# Score 0.13888095170058956
# Going for the 283. with input Kafamı salladım. and output I nodded.
# Output ['I', 'try', '.']
# Target ['I', 'nodded', '.']
# Score 0.4854917717073234
# Going for the 284. with input Ben itaat ettim. and output I obeyed.
# Output ['I', 'obeyed', '.']
# Target ['I', 'obeyed', '.']
# Score 0.8408964152537145
# Going for the 285. with input Duraksadım. and output I paused.
# Output ['I', 'was', 'up', '.']
# Target ['I', 'paused', '.']
# Score 0.37991784282579627
# Going for the 286. with input Dua ettim. and output I prayed.
# Output ['I', 'him', '.']
# Target ['I', 'prayed', '.']
# Score 0.4854917717073234
# Going for the 287. with input Reddediyorum. and output I refuse.
# Output ['I', 'was', 'up', '.']
# Target ['I', 'refuse', '.']
# Score 0.37991784282579627
# Going for the 288. with input İstifa ediyorum. and output I resign.
# Output ['I', 'said', '.']
# Target ['I', 'resign', '.']
# Score 0.4854917717073234
# Going for the 289. with input Onu gördüm. and output I saw it.
# Output ['I', 'saw', 'it', 'it', 'me', '.']
# Target ['I', 'saw', 'it', '.']
# Score 0.42728700639623407
# Going for the 290. with input Tıraş oldum. and output I shaved.
# Output ['I', 'shaved', 'it', 'go']
# Target ['I', 'shaved', '.']
# Score 0.4518010018049224
# Going for the 291. with input Ben gülümsedim. and output I smiled.
# Output ['I', 'was', 'it']
# Target ['I', 'smiled', '.']
# Score 0.408248290463863
# Going for the 292. with input Kaldım. and output I stayed.
# Output ['I', 'was', 'can', 'go']
# Target ['I', 'stayed', '.']
# Score 0.31947155212313627
# Going for the 293. with input Konuştum. and output I talked.
# Output ['I', 'stayed', 'up', '.']
# Target ['I', 'talked', '.']
# Score 0.37991784282579627
# Going for the 294. with input Ben onu kullanırım. and output I use it.
# Output ['I', 'use', 'use', 'go', '<PAD>', '<PAD>', '<PAD>', 'go']
# Target ['I', 'use', 'it', '.']
# Score 0.19640732545025652
# Going for the 295. with input Ben bekledim. and output I waited.
# Output ['I', 'fell', 'it', '<PAD>', '<PAD>', '<PAD>', '<PAD>', 'give']
# Target ['I', 'waited', '.']
# Score 0.13888095170058956
# Going for the 296. with input İyiydim. and output I was OK.
# Output ['I', 'was', 'was', 'up', '.']
# Target ['I', 'was', 'OK', '.']
# Score 0.3760603093086394
# Going for the 297. with input Göz kırptım. and output I winked.
# Output ['I', 'shaved', 'it', 'it']
# Target ['I', 'winked', '.']
# Score 0.31947155212313627
# Going for the 298. with input Esnedim. and output I yawned.
# Output ['I', 'was', 'up', '.']
# Target ['I', 'yawned', '.']
# Score 0.37991784282579627
# Going for the 299. with input Ben esnedim. and output I yawned.
# Output ['I', 'was', '.']
# Target ['I', 'yawned', '.']
# Score 0.4854917717073234
# Going for the 300. with input Soracağım. and output I'll ask.
# Output ["I'll", 'won', '.']
# Target ["I'll", 'ask', '.']
# Score 0.4854917717073234
# Going for the 301. with input Bir sorayım. and output I'll ask.
# Output ["I'll", 'them', '.']
# Target ["I'll", 'ask', '.']
# Score 0.4854917717073234
# Going for the 302. with input Ben sorarım. and output I'll ask.
# Output ["I'll", 'am', '.']
# Target ["I'll", 'ask', '.']
# Score 0.4854917717073234
# Going for the 303. with input Öleceğim. and output I'll die.
# Output ["I'll", 'swam', '.']
# Target ["I'll", 'die', '.']
# Score 0.4854917717073234
# Going for the 304. with input Ben öleceğim. and output I'll die.
# Output ["I'll", 'am']
# Target ["I'll", 'die', '.']
# Score 0.3032653298563167
# Going for the 305. with input Ödeyeceğim. and output I'll pay.
# Output ["I'll", 'pass', '.']
# Target ["I'll", 'pay', '.']
# Score 0.4854917717073234
# Going for the 306. with input Hesabı ben ödeyeceğim. and output I'll pay.
# Output ["I'll", 'you', 'you', 'this', 'DJ', 'me']
# Target ["I'll", 'pay', '.']
# Score 0.19304869754804482
# Going for the 307. with input Ben öderim. and output I'll pay.
# Output ["I'll", 'work', '.']
# Target ["I'll", 'pay', '.']
# Score 0.4854917717073234
# Going for the 308. with input Deneyeceğim. and output I'll try.
# Output ["I'll", 'try', '.']
# Target ["I'll", 'try', '.']
# Score 0.8408964152537145
# Going for the 309. with input Ben kazanacağım. and output I'll win.
# Output ["I'll", 'win', 'here', '<PAD>', '<PAD>', '<PAD>', 'drove', '.']
# Target ["I'll", 'win', '.']
# Score 0.2173604359724957
# Going for the 310. with input Ben bir DJ'im. and output I'm a DJ.
# Output ["I'm", 'a', '.']
# Target ["I'm", 'a', 'DJ', '.']
# Score 0.45782273986766686
# Going for the 311. with input Geri döndüm. and output I'm back.
# Output ["I'm", 'cringed', '.']
# Target ["I'm", 'back', '.']
# Score 0.4854917717073234
# Going for the 312. with input Ben kelim. and output I'm bald.
# Output ["I'm", 'am', 'fat']
# Target ["I'm", 'bald', '.']
# Score 0.408248290463863
# Going for the 313. with input Meşgulüm. and output I'm busy.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'busy', '.']
# Score 0.4854917717073234
# Going for the 314. with input Ben meşgulüm. and output I'm busy.
# Output ["I'm", 'quiet', 'ask']
# Target ["I'm", 'busy', '.']
# Score 0.408248290463863
# Going for the 315. with input Ben sakinim. and output I'm calm.
# Output ["I'm", 'quiet', 'ask', '.']
# Target ["I'm", 'calm', '.']
# Score 0.37991784282579627
# Going for the 316. with input Ben sakinim. and output I'm cool.
# Output ["I'm", 'quiet', 'ask', '.']
# Target ["I'm", 'cool', '.']
# Score 0.37991784282579627
# Going for the 317. with input Ben sağırım. and output I'm deaf.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'deaf', '.']
# Score 0.4854917717073234
# Going for the 318. with input Bitirdim. and output I'm done.
# Output ["I'm", 'gave', '.']
# Target ["I'm", 'done', '.']
# Score 0.4854917717073234
# Going for the 319. with input Ben kolayım. and output I'm easy.
# Output ["I'm", 'quiet', '.']
# Target ["I'm", 'easy', '.']
# Score 0.4854917717073234
# Going for the 320. with input Ben adilim. and output I'm fair.
# Output ["I'm", 'quiet', 'back', '<PAD>', '<PAD>', 'OK']
# Target ["I'm", 'fair', '.']
# Score 0.19304869754804482
# Going for the 321. with input Adilim. and output I'm fair.
# Output ["I'm", 'Be', 'fair', 'quit', '.']
# Target ["I'm", 'fair', '.']
# Score 0.3162277660168379
# Going for the 322. with input Ben hızlıyım. and output I'm fast.
# Output ["I'm", "I'm", 'fat']
# Target ["I'm", 'fast', '.']
# Score 0.408248290463863
# Going for the 323. with input Ben özgürüm! and output I'm free!
# Output ["I'm", 'free', 'in']
# Target ["I'm", 'free', '!']
# Score 0.5773502691896257
# Going for the 324. with input Ben boşum. and output I'm free.
# Output ["I'm", 'over', '.']
# Target ["I'm", 'free', '.']
# Score 0.4854917717073234
# Going for the 325. with input Tokum. and output I'm full.
# Output ["I'm", "I'll", 'hot', '.']
# Target ["I'm", 'full', '.']
# Score 0.37991784282579627
# Going for the 326. with input Ben tokum! and output I'm full.
# Output ['Stop', 'down', '!']
# Target ["I'm", 'full', '.']
# Score 0
# Going for the 327. with input Ben memnunum. and output I'm glad.
# Output ["I'm", "I'm", '.']
# Target ["I'm", 'glad', '.']
# Score 0.4854917717073234
# Going for the 328. with input Ben iyiyim. and output I'm good.
# Output ['I', 'am', "I'm", '.']
# Target ["I'm", 'good', '.']
# Score 0.37991784282579627
# Going for the 329. with input Buradayım. and output I'm here.
# Output ["I'm", "I'll", 'up', '.']
# Target ["I'm", 'here', '.']
# ...
# Output ['Who', 'fell', '?']
# Target ['Who', 'spoke', '?']
# Score 0.4854917717073234
# Going for the 1022. with input Kim ayakta durdu? and output Who stood?
# Output ['Who', 'stood', '?']
# Target ['Who', 'stood', '?']
# Score 0.8408964152537145
# Going for the 1023. with input Kim gidecek? and output Who'll go?
# Output ['Are', 'won', '?']
# Target ["Who'll", 'go', '?']
# Score 0.408248290463863
# Going for the 1024. with input Tom kim? and output Who's Tom?
# Output ["Who's", 'Tom', 'go', '?']
# Target ["Who's", 'Tom', '?']
# Score 0.5
# Going for the 1025. with input Kim hasta? and output Who's ill?
# Output ['Can', 'it', 'go', '?']
# Target ["Who's", 'ill', '?']
# Score 0.31947155212313627
# Going for the 1026. with input O kim? and output Who's she?
# Output ["Who's", 'on', '?']
# Target ["Who's", 'she', '?']
# Score 0.4854917717073234
# Going for the 1027. with input O kimdir? and output Who's she?
# Output ["Who's", 'for', '?']
# Target ["Who's", 'she', '?']
# Score 0.4854917717073234
# Going for the 1028. with input Harika! and output Wonderful!
# Output ['Wonderful', '!']
# Target ['Wonderful', '!']
# Score 0.7071067811865476
# Going for the 1029. with input Tom'a yaz. and output Write Tom.
# Output ['Write', 'Tom', 'Tom', '.']
# Target ['Write', 'Tom', '.']
# Score 0.5533409598501607
# Going for the 1030. with input Sen sür. and output You drive.
# Output ['You', 'lost', '.']
# Target ['You', 'drive', '.']
# Score 0.4854917717073234
# Going for the 1031. with input Seni aptal! and output You idiot!
# Output ['You', 'up', '.']
# Target ['You', 'idiot', '!']
# Score 0.408248290463863
# Going for the 1032. with input Seni aptal!! and output You idiot!
# Output ['You', 'up', '.']
# Target ['You', 'idiot', '!']
# Score 0.408248290463863
# Going for the 1033. with input Sen başla. and output You start.
# Output ['You', 'hung', '.']
# Target ['You', 'start', '.']
# Score 0.4854917717073234
# Going for the 1034. with input Pis kokuyorsun. and output You stink.
# Output ['You', 'agreed', '.']
# Target ['You', 'stink', '.']
# Score 0.4854917717073234
# Going for the 1035. with input İğrenç kokuyorsun. and output You stink.
# Output ['You', 'agreed', '.']
# Target ['You', 'stink', '.']
# Score 0.4854917717073234
# Going for the 1036. with input Sen çabaladın. and output You tried.
# Output ['You', 'hung', '.']
# Target ['You', 'tried', '.']
# Score 0.4854917717073234
# Going for the 1037. with input Sen iyisin. and output You're OK.
# Output ['Go', 'lost', '.']
# Target ["You're", 'OK', '.']
# Score 0.408248290463863
# Going for the 1038. with input Daha yükseği hedefle. and output Aim higher.
# Output ['Aim', 'it', 'this', '!']
# Target ['Aim', 'higher', '.']
# Score 0.31947155212313627
# Going for the 1039. with input Aşağıda yolcu kalmasın! and output All aboard!
# Output ['All', 'it', 'it', 'it', '!']
# Target ['All', 'aboard', '!']
# Score 0.28574404296988
# Going for the 1040. with input Haydi binin! and output All aboard!
# Output ['All', 'it', 'it', '!']
# Target ['All', 'aboard', '!']
# Score 0.37991784282579627
# Going for the 1041. with input Herkes gemiye! and output All aboard!
# Output ['All', 'this', '!']
# Target ['All', 'aboard', '!']
# Score 0.4854917717073234
# Going for the 1042. with input Ben açık mıyım? and output Am I clear?
# Output ['Am', 'I', 'cute', '?']
# Target ['Am', 'I', 'clear', '?']
# Score 0.5
# Going for the 1043. with input Ölüyor muyum? and output Am I dying?
# Output ['Am', 'I', 'new', '?']
# Target ['Am', 'I', 'dying', '?']
# Score 0.5
# Going for the 1044. with input Erken mi geldim? and output Am I early?
# Output ['Am', 'I', 'quit', '?']
# Target ['Am', 'I', 'early', '?']
# Score 0.5
# Going for the 1045. with input Ben kovuldum mu? and output Am I fired?
# Output ['Am', 'I', 'cringed', 'cute', 'pay', '?']
# Target ['Am', 'I', 'fired', '?']
# Score 0.3021375397356768
# Going for the 1046. with input Ben birinci miyim? and output Am I first?
# Output ['Am', 'I', 'stink', 'win', 'win', 'win', '!']
# Target ['Am', 'I', 'first', '?']
# Score 0.2283945119649991
# Going for the 1047. with input İşe alındım mı? and output Am I hired?
# Output ['Am', 'me', 'I', 'I', 'We', "Don't", 'Stay', '?']
# Target ['Am', 'I', 'hired', '?']
# Score 0.18277761142725618
# Going for the 1048. with input Hazır mıyım? and output Am I ready?
# Output ['Am', 'I', 'Tom', '?']
# Target ['Am', 'I', 'ready', '?']
# Score 0.5
# Going for the 1049. with input Ben haklı mıyım? and output Am I right?
# Output ['Am', 'I', 'cringed', '?']
# Target ['Am', 'I', 'right', '?']
# Score 0.5
# Going for the 1050. with input Yanılıyor muyum? and output Am I wrong?
# Output ['Am', 'I', 'win', 'ask', '<PAD>', 'it', 'it', 'it']
# Target ['Am', 'I', 'wrong', '?']
# Score 0.19640732545025652
# Going for the 1051. with input Tom'a cevap ver. and output Answer Tom.
# Output ['Answer', 'Tom', 'Tom', 'me', 'me', '<PAD>', '<PAD>', 'me']
# Target ['Answer', 'Tom', '.']
# Score 0.19640732545025652
# Going for the 1052. with input 18 yaşında mısın? and output Are you 18?
# Output ['Are', 'you', 'you', 'you', 'quit', 'quit', '?']
# Target ['Are', 'you', '18', '?']
# Score 0.2527600769504433
# Going for the 1053. with input İyi misin? and output Are you OK?
# Output ['Are', 'swam', '?']
# Target ['Are', 'you', 'OK', '?']
# Score 0.3478700554542393
# Going for the 1054. with input Evde misin? and output Are you in?
# Output ['Are', 'ate', 'quit', '?']
# Target ['Are', 'you', 'in', '?']
# Score 0.37991784282579627
# Going for the 1055. with input Uyanık mısın? and output Are you up?
# Output ['Are', 'ate', '?']
# Target ['Are', 'you', 'up', '?']
# Score 0.3478700554542393
# Going for the 1056. with input Birine sor. and output Ask anyone.
# Output ['Ask', 'around', 'him', '.']
# Target ['Ask', 'anyone', '.']
# Score 0.37991784282579627
# Going for the 1057. with input Çevrene sor. and output Ask around.
# Output ['Ask', 'around', 'him', 'is', '<PAD>', "I'm", "I'm", 'calls']
# Target ['Ask', 'around', '.']
# Score 0.19640732545025652
# Going for the 1058. with input Hayatından memnun ol. and output Be content.
# Output ['Be', 'a', 'lying', '.']
# Target ['Be', 'content', '.']
# Score 0.37991784282579627
# Going for the 1059. with input Zamanında gelin. and output Be on time.
# Output ['Be', 'am', 'a', '.']
# Target ['Be', 'on', 'time', '.']
# Score 0.37991784282579627
# Going for the 1060. with input Sabırlı ol. and output Be patient.
# Output ['Be', 'am', 'win', '.']
# Target ['Be', 'patient', '.']
# Score 0.37991784282579627
# Going for the 1061. with input Ciddi ol. and output Be serious.
# Output ['Be', 'am', 'shy', '.']
# Target ['Be', 'serious', '.']
# Score 0.37991784282579627
# Going for the 1062. with input Ciddi olun. and output Be serious.
# Output ['Be', 'am', 'cool', '.']
# Target ['Be', 'serious', '.']
# Score 0.37991784282579627
# Going for the 1063. with input Kuşlar öter. and output Birds sing.
# Output ['Birds', 'this', 'me', '.']
# Target ['Birds', 'sing', '.']
# Score 0.37991784282579627
# Going for the 1064. with input Yarasın! and output Bottoms up!
# Output ['Thanks', '!']
# Target ['Bottoms', 'up', '!']
# Score 0.3032653298563167
# Going for the 1065. with input Nefes alın. and output Breathe in.
# Output ['Go', 'won', '.']
# Target ['Breathe', 'in', '.']
# Score 0.408248290463863
# Going for the 1066. with input Soluk alın. and output Breathe in.
# Output ['Be', 'ate', '.']
# Target ['Breathe', 'in', '.']
# Score 0.408248290463863
# Going for the 1067. with input Nefesinizi çekin. and output Breathe in.
# Output ['Breathe', 'won', '.']
# Target ['Breathe', 'in', '.']
# Score 0.4854917717073234
# Going for the 1068. with input Yiyecek getir. and output Bring food.
# Output ['Bring', 'agree', 'him', '.']
# Target ['Bring', 'food', '.']
# Score 0.37991784282579627
# Going for the 1069. with input Yardım getir. and output Bring help.
# Output ['Bring', 'agree', '.']
# Target ['Bring', 'help', '.']
# Score 0.4854917717073234
# Going for the 1070. with input Şarap getir. and output Bring wine.
# Output ['Bring', 'agree', 'him', '.']
# Target ['Bring', 'wine', '.']
# Score 0.37991784282579627
# Going for the 1071. with input Gelebilir miyim? and output Can I come?
# Output ['Can', 'it', 'won', '?']
# Target ['Can', 'I', 'come', '?']
# Score 0.37991784282579627
# Going for the 1072. with input Yardım edebilir miyim? and output Can I help?
# Output ['Can', 'it', 'it', '?']
# Target ['Can', 'I', 'help', '?']
# Score 0.37991784282579627
# Going for the 1073. with input Şarkı söyleyebilir miyim? and output Can I sing?
# Output ['Can', 'I', 'eat', '?']
# Target ['Can', 'I', 'sing', '?']
# Score 0.5
# Going for the 1074. with input Kalabilir miyim? and output Can I stay?
# Output ['Can', 'I', 'stay', '?']
# Target ['Can', 'I', 'stay', '?']
# Score 1.0
# Going for the 1075. with input Bunu taşıyın. and output Carry this.
# Output ['Carry', 'this', 'it', 'me']
# Target ['Carry', 'this', '.']
# Score 0.4518010018049224
# Going for the 1076. with input Bunu yakala. and output Catch this.
# Output ['Catch', 'him', 'it', 'it', 'it']
# Target ['Catch', 'this', '.']
# Score 0.24028114141347542
# Going for the 1077. with input Onu kontrol et. and output Check that.
# Output ['Check', 'this', 'it', '.']
# Target ['Check', 'that', '.']
# Score 0.37991784282579627
# Going for the 1078. with input Bunu kontrol et. and output Check this.
# Output ['Check', 'this', '.']
# Target ['Check', 'this', '.']
# Score 0.8408964152537145
# Going for the 1079. with input Birini seçin. and output Choose one.
# Output ['Write', 'this', 'it', '.']
# Target ['Choose', 'one', '.']
# Score 0.31947155212313627
# Going for the 1080. with input Tekrar gel. and output Come again.
# Output ['Come', 'home', '.']
# Target ['Come', 'again', '.']
# Score 0.4854917717073234
# Going for the 1081. with input Yalnız gel. and output Come alone.
# Output ['Come', 'alone', '.']
# Target ['Come', 'alone', '.']
# Score 0.8408964152537145
# Going for the 1082. with input Bizimle gel. and output Come along.
# Output ['Come', 'to', '.']
# Target ['Come', 'along', '.']
# Score 0.4854917717073234
# Going for the 1083. with input Erken gel. and output Come early.
# Output ['Come', 'ate', '.']
# Target ['Come', 'early', '.']
# Score 0.4854917717073234
# Going for the 1084. with input Girin. and output Come on in.
# Output ['I', 'stayed', 'up', '.']
# Target ['Come', 'on', 'in', '.']
# Score 0.31947155212313627
# Going for the 1085. with input İçeri gel. and output Come on in.
# Output ['Come', 'drove', '.']
# Target ['Come', 'on', 'in', '.']
# Score 0.3478700554542393
# Going for the 1086. with input Çabuk gelin. and output Come quick!
# Output ['Come', 'give', '.']
# Target ['Come', 'quick', '!']
# Score 0.408248290463863
# Going for the 1087. with input Bana gel. and output Come to me.
# Output ['Come', 'that', '.']
# Target ['Come', 'to', 'me', '.']
# Score 0.3478700554542393
# Going for the 1088. with input Bize gel. and output Come to us.
# Output ['Come', 'to', '.']
# Target ['Come', 'to', 'us', '.']
# Score 0.45782273986766686
# Going for the 1089. with input Kes artık! and output Cut it out!
# Output ['Cut', 'down', '!']
# Target ['Cut', 'it', 'out', '!']
# Score 0.3478700554542393
# Going for the 1090. with input Uzatma artık! and output Cut it out!
# Output ['Cut', 'down', '!']
# Target ['Cut', 'it', 'out', '!']
# Score 0.3478700554542393
# Going for the 1091. with input Kes şunu! and output Cut it out.
# Output ["Let's", '!']
# Target ['Cut', 'it', 'out', '.']
# Score 0
# Going for the 1092. with input Benimle ticaret yap. and output Deal me in.
# Output ['Deal', 'me', 'me', 'me', 'me']
# Target ['Deal', 'me', 'in', '.']
# Score 0.33980884896942454
# Going for the 1093. with input Kesinlikle! and output Definitely!
# Output ['Attack', '!']
# Target ['Definitely', '!']
# Score 0.5
# Going for the 1094. with input Onu yok et. and output Destroy it.
# Output ['Destroy', 'it', 'it', 'me', 'me', '<PAD>', 'it', 'it', 'it']
# Target ['Destroy', 'it', '.']
# Score 0.1723243846523902
# Going for the 1095. with input Tom gitti mi? and output Did Tom go?
# Output ['Did', 'Tom', 'Tom', 'win', 'go', '?']
# Target ['Did', 'Tom', 'go', '?']
# Score 0.35930411196308426
# Going for the 1096. with input Kazandık mı? and output Did we win?
# Output ['Did', 'I', 'Seriously', '?']
# Target ['Did', 'we', 'win', '?']
# Score 0.37991784282579627
# Going for the 1097. with input Kötü kokuyor muyum? and output Do I stink?
# Output ['Do', 'I', 'stink', 'Take', '?']
# Target ['Do', 'I', 'stink', '?']
# Score 0.5318295896944989
# Going for the 1098. with input İçeriye gel. and output Do come in.
# Output ['Do', 'drove', 'away', '.']
# Target ['Do', 'come', 'in', '.']
# Score 0.37991784282579627
# Going for the 1099. with input Erkekler ağlar mı? and output Do men cry?
# Output ['Do', 'I', 'ate', 'cute', 'cry', '?']
# Target ['Do', 'men', 'cry', '?']
# Score 0.3021375397356768
# Going for the 1100. with input Kayar mısın? and output Do you ski?
# Output ['Do', 'am', 'ask', 'ski', 'win', '<PAD>', 'win', '.']
# Target ['Do', 'you', 'ski', '?']
# Score 0.16515821590069035
# Going for the 1101. with input Böbürlenme. and output Don't brag.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'brag', '.']
# Score 0.4854917717073234
# Going for the 1102. with input Böbürlenmeyin. and output Don't brag.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'brag', '.']
# Score 0.4854917717073234
# Going for the 1103. with input Gelme. and output Don't come.
# Output ["Don't", "I'll", 'ask']
# Target ["Don't", 'come', '.']
# Score 0.408248290463863
# Going for the 1104. with input Atlama! and output Don't jump!
# Output ["Don't", '!']
# Target ["Don't", 'jump', '!']
# Score 0.36064528799877893
# Going for the 1105. with input Tekme atma. and output Don't kick.
# Output ["Don't", '.']
# Target ["Don't", 'kick', '.']
# Score 0.36064528799877893
# Going for the 1106. with input Bakma. and output Don't look.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'look', '.']
# Score 0.4854917717073234
# Going for the 1107. with input Kımıldama. and output Don't move.
# Output ['Stay', 'Stay', '.']
# Target ["Don't", 'move', '.']
# Score 0.408248290463863
# Going for the 1108. with input Dikizlemeyin. and output Don't peek.
# Output ["Don't", "Don't", '.']
# Target ["Don't", 'peek', '.']
# Score 0.4854917717073234
# Going for the 1109. with input Gözetlemeyin. and output Don't peek.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'peek', '.']
# Score 0.4854917717073234
# Going for the 1110. with input İtme. and output Don't push.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'push', '.']
# Score 0.4854917717073234
# Going for the 1111. with input Bırakma. and output Don't quit.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'quit', '.']
# Score 0.4854917717073234
# Going for the 1112. with input Acele etme. and output Don't rush.
# Output ["Don't", 'am', 'back', '.']
# Target ["Don't", 'rush', '.']
# Score 0.37991784282579627
# Going for the 1113. with input Şarkı söyleme. and output Don't sing.
# Output ['Leave', 'now', 'it', 'it']
# Target ["Don't", 'sing', '.']
# Score 0
# Going for the 1114. with input Kayma. and output Don't slip.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'slip', '.']
# Score 0.4854917717073234
# Going for the 1115. with input Durma. and output Don't stop.
# Output ["Don't", 'will', '.']
# Target ["Don't", 'stop', '.']
# Score 0.4854917717073234
# Going for the 1116. with input Yüzme. and output Don't swim.
# Output ["Don't", 'won', '.']
# Target ["Don't", 'swim', '.']
# Score 0.4854917717073234
# Going for the 1117. with input Konuşma! and output Don't talk!
# Output ["Don't", '!']
# Target ["Don't", 'talk', '!']
# Score 0.36064528799877893
# Going for the 1118. with input Bekleme. and output Don't wait.
# Output ["Don't", 'will', '.']
# Target ["Don't", 'wait', '.']
# Score 0.4854917717073234
# Going for the 1119. with input Görev bekler. and output Duty calls.
# Output ['Duty', 'it', 'you', '.']
# Target ['Duty', 'calls', '.']
# Score 0.37991784282579627
# Going for the 1120. with input Görev çağırır. and output Duty calls.
# Output ['Duty', 'it', 'you', '.']
# Target ['Duty', 'calls', '.']
# Score 0.37991784282579627
# Going for the 1121. with input Yavaş ye. and output Eat slowly.
# Output ['I', 'it', 'it', 'it']
# Target ['Eat', 'slowly', '.']
# Score 0
# Going for the 1122. with input Onu inceleyin. and output Examine it.
# Output ['I', 'this', 'it', '.']
# Target ['Examine', 'it', '.']
# Score 0.4518010018049224
# Going for the 1123. with input Gerçeklerle yüzleş! and output Face facts!
# Output ['Of', 'him', '!']
# Target ['Face', 'facts', '!']
# Score 0.408248290463863
# Total Avg Score 0.3939922623156501

# %%
torch.save(model.state_dict, 'models/seq2seq_2word_ep300.pth')
